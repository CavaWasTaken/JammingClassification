# %%
from signal_analysis import SignalAnalysis
import os
import numpy as np
import pandas as pd

# %% [markdown]
# **Connection to Google Drive**
# - Locally: use rclone to mount Google Drive to a local folder
# - Google Colab

# %%
from google.colab import drive, files
drive.mount('/content/drive')
data_path = '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi'
# Out:
# Mounted at /content/drive

# %%
# # Unmount if already mounted, then mount with proper caching
# # !fusermount -u ~/GoogleDrive 2>/dev/null || true
# !rclone mount gdrive: ~/GoogleDrive --vfs-cache-mode full --daemon --vfs-read-chunk-size 128M --buffer-size 128M

# data_path = '/home/cavallinux/GoogleDrive/N-MON/Dataset_LINKS_preso_da_noi'
# Out:
# Fatal error: directory already mounted, use --allow-non-empty to mount anyway: /home/cavallinux/GoogleDrive

# %% [markdown]
# **Environment Setup**

# %%
# Input file details
# __basedir__ = os.path.abspath("../..")
# path_of_file = os.path.join(__basedir__, 'IQ_DATA') # Path to the folder containing IQ files
fs_ = 10e6  # Sampling frequency
fc_ = 1575.42e6 # Carrier frequency
output_type_ = "fc32"    # Output type of the file - float32
chunk_separation_file = 100e-3  # Chunk separation in seconds (100 ms) - if we want to increase the amount of read data increase this value
skip_second = 5  # Seconds to skip at the beginning of the file
type_to_do = ['HOOKED-SAWTOOTH-3-20']  # 'LWF', 'LN', 'TICK', 'TRI', 'TRIW'

# %% [markdown]
# **Folder Structure**

# %%
jammer_folder = [os.path.join(data_path, f) for f in os.listdir(data_path)]
jammer_folder
# Out:
# ['/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_112953_LWF',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_115231_LN',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_135534_TICK',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_142018_TRI',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_154305_TRIW',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_160202_CLEAN',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/Observation_N_MON.zip',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260304_163557_CLEAN_antennina',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260310_180247_CLEAN_antennina2',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260521_155733_MULTITONE-NARROW-40-20',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260521_155253_LINEAR-WIDE-20',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260521_154528_FH-20',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260521_153329_HOOKED-SAWTOOTH-3-20']

# %% [markdown]
# **Data processing of P1, P2, P3, P4**

# %%
for jammer_path in jammer_folder:
    interference_type = jammer_path.split('_')[-1]  # extract the jamming type from the folder name
    if interference_type not in type_to_do: # skip if the interference type is not the same that we want to process
        continue
    print(f"Processing interference type: {interference_type}")

    #Create Columns
    features_name = [f'f{i}' for i in range(1, 17)] + ['power', 'path_spec', 'class']
    rows = []

    drive_output_root = '/content/drive/MyDrive/N-MON/ALTRO/spectograms'
    drive_csv_dir = '/content/drive/MyDrive/N-MON/ALTRO/features_csv'

    base_array_dir = os.path.join(drive_output_root, interference_type)
    os.makedirs(base_array_dir, exist_ok=True)
    os.makedirs(drive_csv_dir, exist_ok=True)

    file_size = os.path.getsize(jammer_path)    # get the size of the file
    total_sec = round(file_size / fs_ / {'fc32': 8, 'sc16': 4, 'sc8': 2}[output_type_]) # calculate the total duration of the file in seconds

    print(f'File size: {file_size:,} bytes')
    print(f'Total seconds for {jammer_path}: {total_sec} ({total_sec/60:.1f} minutes)')

    signal_analysis_object = SignalAnalysis(fs=fs_, fc=fc_, output_type=output_type_, file_name=jammer_path)    # create the SignalAnalysis object

    # MAIN LOOP for creating dataset
    # Each jamming file contains 8 different power levels. Each power level lasts 2 minutes (120 seconds)
    # For each power level: skip first 5 seconds and last 5 seconds, process the middle 110 seconds
    power_duration = 120  # seconds per power level
    valid_duration_per_power = power_duration - 2 * skip_second  # 110 seconds of valid data per power level
    num_power_levels = 8

    for power_idx in range(int(num_power_levels/2)):
        jammer_power = f"P{power_idx + 1}"  # P1, P2, P3, P4
        power_dir = os.path.join(base_array_dir, f"{jammer_power}")
        os.makedirs(power_dir, exist_ok=True)

        # Calculate time range for this power level
        power_start = power_idx * power_duration + skip_second  # Skip first 5 seconds
        power_end = (power_idx + 1) * power_duration - skip_second  # Skip last 5 seconds

        # Make sure we don't exceed file duration
        if power_start >= total_sec:
            print(f"Skipping power level {jammer_power} - beyond file duration")
            break
        if power_end > total_sec:
            power_end = total_sec

        print(f"Processing {jammer_power}: from {power_start}s to {power_end}s ({power_end - power_start:.1f}s)")

        # Process chunks within this power level
        loop_range = np.arange(power_start, power_end, chunk_separation_file)
        print(f"  Will process {len(loop_range)} chunks for {jammer_power}")

        try:
            for i, start_point_file in enumerate(loop_range):
                spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
                file_name_npy = os.path.join(power_dir, f"{jammer_power}_{i}.npy")
                np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array

                features_signal = signal_analysis_object.extract_features(start_point=start_point_file)
                rows.append(features_signal + [jammer_power, file_name_npy, interference_type])

                print(f"  Saved {file_name_npy}")
                print(f"  {jammer_power}: Processed chunk {i+1}/{len(loop_range)}")

            print(f"  {jammer_power}: Completed {len(loop_range)} chunks                    ")

        except Exception as e:
            print(f"\nERROR in {jammer_power} at chunk {i}: {str(e)}")
            import traceback
            traceback.print_exc()
            print("Continuing to next power level...")
            continue

    print(f"\nTotal rows collected: {len(rows)}")
    df = pd.DataFrame(rows, columns=features_name)
    output_csv_path = os.path.join(drive_csv_dir, f'features_file_{interference_type}_1.csv')
    df.to_csv(output_csv_path, sep=',')
    print(f"Completed {interference_type}, saved to {output_csv_path}")
# Out:
# Processing interference type: antennina2
# File size: 25,424,826,936 bytes
# Total seconds for /content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260310_180247_CLEAN_antennina2: 318 (5.3 minutes)
# Processing P1: from 5s to 115s (110.0s)
#   Will process 1100 chunks for P1
# Using memory-mapped file access for LINKS_L1_10Mhz_complex_int8_20260310_180247_CLEAN_antennina2
#
# ERROR in P1 at chunk 0: [Errno 2] No such file or directory: './array_dataset/antennina2/P1/P1_0.npy'
# Continuing to next power level...
# Processing P2: from 125s to 235s (110.0s)
#   Will process 1100 chunks for P2
# Traceback (most recent call last):
#   File "/tmp/ipykernel_395/2225114963.py", line 59, in <cell line: 0>
#     np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 570, in save
#     file_ctx = open(file, "wb")
#                ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './array_dataset/antennina2/P1/P1_0.npy'
# ERROR in P2 at chunk 0: [Errno 2] No such file or directory: './array_dataset/antennina2/P2/P2_0.npy'
# Continuing to next power level...
# Processing P3: from 245s to 318s (73.0s)
#   Will process 730 chunks for P3
# Traceback (most recent call last):
#   File "/tmp/ipykernel_395/2225114963.py", line 59, in <cell line: 0>
#     np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 570, in save
#     file_ctx = open(file, "wb")
#                ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './array_dataset/antennina2/P2/P2_0.npy'
# ERROR in P3 at chunk 0: [Errno 2] No such file or directory: './array_dataset/antennina2/P3/P3_0.npy'
# Continuing to next power level...
# Skipping power level P4 - beyond file duration
#
# Total rows collected: 0
# Completed antennina2, saved to ./features_file_antennina2_1.csv
# Traceback (most recent call last):
#   File "/tmp/ipykernel_395/2225114963.py", line 59, in <cell line: 0>
#     np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 570, in save
#     file_ctx = open(file, "wb")
#                ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './array_dataset/antennina2/P3/P3_0.npy'

# %%
# download the folder array_dataset
# !zip -r array_dataset1.zip ./array_dataset
files.download(f"features_file_{type_to_do}_1.csv")

# %% [markdown]
# **Data Processing of P5, P6, P7, P8**

# %%
for jammer_path in jammer_folder:
    interference_type = jammer_path.split('_')[-1]  # extract the jamming type from the folder name
    if interference_type not in type_to_do: # skip if the interference type is not the same that we want to process
        continue
    print(f"Processing interference type: {interference_type}")

    #Create Columns
    features_name = [f'f{i}' for i in range(1, 17)] + ['power', 'path_spec', 'class']
    rows = []

    drive_output_root = '/content/drive/MyDrive/N-MON/ALTRO/spectograms'
    drive_csv_dir = '/content/drive/MyDrive/N-MON/ALTRO/features_csv'

    base_array_dir = os.path.join(drive_output_root, interference_type)
    os.makedirs(base_array_dir, exist_ok=True)
    os.makedirs(drive_csv_dir, exist_ok=True)

    file_size = os.path.getsize(jammer_path)    # get the size of the file
    total_sec = round(file_size / fs_ / {'fc32': 8, 'sc16': 4, 'sc8': 2}[output_type_]) # calculate the total duration of the file in seconds

    print(f'File size: {file_size:,} bytes')
    print(f'Total seconds for {jammer_path}: {total_sec} ({total_sec/60:.1f} minutes)')

    signal_analysis_object = SignalAnalysis(fs=fs_, fc=fc_, output_type=output_type_, file_name=jammer_path)    # create the SignalAnalysis object

    # MAIN LOOP for creating dataset
    # Each jamming file contains 8 different power levels. Each power level lasts 2 minutes (120 seconds)
    # For each power level: skip first 5 seconds and last 5 seconds, process the middle 110 seconds
    power_duration = 120  # seconds per power level
    valid_duration_per_power = power_duration - 2 * skip_second  # 110 seconds of valid data per power level
    num_power_levels = 8

    for power_idx in range(int(num_power_levels/2)):
        power_idx += 4
        jammer_power = f"P{power_idx + 1}"  # P5, P6, P7, P8
        power_dir = os.path.join(base_array_dir, f"{jammer_power}")
        os.makedirs(power_dir, exist_ok=True)

        # Calculate time range for this power level
        power_start = power_idx * power_duration + skip_second  # Skip first 5 seconds
        power_end = (power_idx + 1) * power_duration - skip_second  # Skip last 5 seconds

        # Make sure we don't exceed file duration
        if power_start >= total_sec:
            print(f"Skipping power level {jammer_power} - beyond file duration")
            break
        if power_end > total_sec:
            power_end = total_sec

        print(f"Processing {jammer_power}: from {power_start}s to {power_end}s ({power_end - power_start:.1f}s)")

        # Process chunks within this power level
        loop_range = np.arange(power_start, power_end, chunk_separation_file)
        print(f"  Will process {len(loop_range)} chunks for {jammer_power}")

        try:
            for i, start_point_file in enumerate(loop_range):
                spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
                file_name_npy = os.path.join(power_dir, f"{jammer_power}_{i}.npy")
                np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array

                features_signal = signal_analysis_object.extract_features(start_point=start_point_file)
                rows.append(features_signal + [jammer_power, file_name_npy, interference_type])

                print(f"  Saved {file_name_npy}")

                print(f"  {jammer_power}: Processed chunk {i+1}/{len(loop_range)}")

            print(f"  {jammer_power}: Completed {len(loop_range)} chunks                    ")

        except Exception as e:
            print(f"\nERROR in {jammer_power} at chunk {i}: {str(e)}")
            import traceback
            traceback.print_exc()
            print("Continuing to next power level...")
            continue

    print(f"\nTotal rows collected: {len(rows)}")
    df = pd.DataFrame(rows, columns=features_name)
    output_csv_path = os.path.join(drive_csv_dir, f'features_file_{interference_type}_2.csv')
    df.to_csv(output_csv_path, sep=',')
    print(f"Completed {interference_type}, saved to {output_csv_path}")

# %%
# download the folder array_dataset
# !zip -r array_dataset2.zip ./image_dataset/CLEAN/
files.download(f"features_file_{type_to_do}_2.csv")

# %% [markdown]
# **Data Processing of CLEAN data**

# %%
for jammer_path in jammer_folder:
    interference_type = os.path.basename(jammer_path).split('_')[-1]  # extract jamming type from filename
    if interference_type not in type_to_do:  # skip if not in selected types
        continue
    print(f"Processing interference type: {interference_type}")

    # Create Columns
    features_name = [f'f{i}' for i in range(1, 17)] + ['path_spec', 'class']
    rows = []

    # --- DIRECT WRITE TO GOOGLE DRIVE ---
    drive_output_root = '/content/drive/MyDrive/N-MON/ALTRO/spectograms'
    drive_csv_dir = '/content/drive/MyDrive/N-MON/ALTRO/features_csv'

    base_array_dir = os.path.join(drive_output_root, interference_type)
    os.makedirs(base_array_dir, exist_ok=True)
    os.makedirs(drive_csv_dir, exist_ok=True)

    file_size = os.path.getsize(jammer_path)  # get file size
    total_sec = round(file_size / fs_ / {'fc32': 8, 'sc16': 4, 'sc8': 2}[output_type_])  # total duration in seconds

    print(f'File size: {file_size:,} bytes')
    print(f'Total seconds for {jammer_path}: {total_sec} ({total_sec/60:.1f} minutes)')
    print(f'Writing NPY to: {base_array_dir}')

    signal_analysis_object = SignalAnalysis(
        fs=fs_,
        fc=fc_,
        output_type=output_type_,
        file_name=jammer_path
    )

    # Calculate time range
    start = skip_second
    end = total_sec - skip_second

    # Process chunks
    loop_range = np.arange(start, end, chunk_separation_file)
    print(f"  Will process {len(loop_range)} chunks for {interference_type}")

    try:
        for i, start_point_file in enumerate(loop_range):
            spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
            file_name_npy = os.path.join(base_array_dir, f"{i}.npy")
            np.save(file_name_npy, spec_array)

            features_signal = signal_analysis_object.extract_features(start_point=start_point_file)
            rows.append(features_signal + [file_name_npy, interference_type])

            print(f"  Saved {file_name_npy}")
            print(f"  Processed chunk {i+1}/{len(loop_range)}")

        print(f"  Completed {len(loop_range)} chunks                    ")

    except Exception as e:
        print(f"\nERROR in {interference_type} at chunk {i}: {str(e)}")
        import traceback
        traceback.print_exc()
        print("Continuing to next interference type...")
        continue

    print(f"\nTotal rows collected: {len(rows)}")
    df = pd.DataFrame(rows, columns=features_name)
    output_csv_path = os.path.join(drive_csv_dir, f'features_file_{interference_type}.csv')
    df.to_csv(output_csv_path, sep=',', index=False)
    print(f"Completed {interference_type}, saved to {output_csv_path}")
# Out:
# Processing interference type: HOOKED-SAWTOOTH-3-20
# File size: 16,822,776,784 bytes
# Total seconds for /content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260521_153329_HOOKED-SAWTOOTH-3-20: 210 (3.5 minutes)
# Writing NPY to: /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20
#   Will process 2000 chunks for HOOKED-SAWTOOTH-3-20
# Using memory-mapped file access for LINKS_L1_10Mhz_complex_int8_20260521_153329_HOOKED-SAWTOOTH-3-20
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/0.npy
#   Processed chunk 1/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1.npy
#   Processed chunk 2/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/2.npy
#   Processed chunk 3/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20
2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1939.npy
#   Processed chunk 1940/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1940.npy
#   Processed chunk 1941/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1941.npy
#   Processed chunk 1942/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1942.npy
#   Processed chunk 1943/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1943.npy
#   Processed chunk 1944/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1944.npy
#   Processed chunk 1945/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1945.npy
#   Processed chunk 1946/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1946.npy
#   Processed chunk 1947/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1947.npy
#   Processed chunk 1948/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1948.npy
#   Processed chunk 1949/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1949.npy
#   Processed chunk 1950/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1950.npy
#   Processed chunk 1951/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1951.npy
#   Processed chunk 1952/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1952.npy
#   Processed chunk 1953/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1953.npy
#   Processed chunk 1954/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1954.npy
#   Processed chunk 1955/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1955.npy
#   Processed chunk 1956/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1956.npy
#   Processed chunk 1957/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1957.npy
#   Processed chunk 1958/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1958.npy
#   Processed chunk 1959/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1959.npy
#   Processed chunk 1960/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1960.npy
#   Processed chunk 1961/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1961.npy
#   Processed chunk 1962/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1962.npy
#   Processed chunk 1963/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1963.npy
#   Processed chunk 1964/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1964.npy
#   Processed chunk 1965/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1965.npy
#   Processed chunk 1966/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1966.npy
#   Processed chunk 1967/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1967.npy
#   Processed chunk 1968/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1968.npy
#   Processed chunk 1969/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1969.npy
#   Processed chunk 1970/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1970.npy
#   Processed chunk 1971/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1971.npy
#   Processed chunk 1972/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1972.npy
#   Processed chunk 1973/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1973.npy
#   Processed chunk 1974/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1974.npy
#   Processed chunk 1975/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1975.npy
#   Processed chunk 1976/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1976.npy
#   Processed chunk 1977/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1977.npy
#   Processed chunk 1978/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1978.npy
#   Processed chunk 1979/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1979.npy
#   Processed chunk 1980/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1980.npy
#   Processed chunk 1981/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1981.npy
#   Processed chunk 1982/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1982.npy
#   Processed chunk 1983/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1983.npy
#   Processed chunk 1984/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1984.npy
#   Processed chunk 1985/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1985.npy
#   Processed chunk 1986/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1986.npy
#   Processed chunk 1987/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1987.npy
#   Processed chunk 1988/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1988.npy
#   Processed chunk 1989/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1989.npy
#   Processed chunk 1990/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1990.npy
#   Processed chunk 1991/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1991.npy
#   Processed chunk 1992/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1992.npy
#   Processed chunk 1993/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1993.npy
#   Processed chunk 1994/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1994.npy
#   Processed chunk 1995/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1995.npy
#   Processed chunk 1996/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1996.npy
#   Processed chunk 1997/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1997.npy
#   Processed chunk 1998/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1998.npy
#   Processed chunk 1999/2000
#   Saved /content/drive/MyDrive/N-MON/ALTRO/spectograms/HOOKED-SAWTOOTH-3-20/1999.npy
#   Processed chunk 2000/2000
#   Completed 2000 chunks
#
# Total rows collected: 2000
# Completed HOOKED-SAWTOOTH-3-20, saved to /content/drive/MyDrive/N-MON/ALTRO/features_csv/features_file_HOOKED-SAWTOOTH-3-20.csv

# %%
import os, re

files = [f for f in os.listdir(base_array_dir) if f.endswith(".npy")]
idx = sorted(int(re.match(r"(\d+)\.npy$", f).group(1)) for f in files if re.match(r"(\d+)\.npy$", f))

expected = set(range(3080))
actual = set(idx)
missing = sorted(expected - actual)

print("count:", len(files))
print("min/max:", min(idx), max(idx))
print("missing:", missing[:30], "..." if len(missing) > 30 else "")
# Out:
# count: 3080
# min/max: 0 3079
# missing: []
