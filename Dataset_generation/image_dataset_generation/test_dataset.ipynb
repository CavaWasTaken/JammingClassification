# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
npy_path = "/content/drive/MyDrive/N-MON/Processed_Dataset/TRIW/P8/P8_1026.npy"
npy_path2 = "/content/drive/MyDrive/N-MON/Processed_Dataset/CLEAN_ANTENNINA/163.npy"

# load

#arr = np.load(npy_path).astype(np.int8)
arr = np.load(npy_path)
arr2 = np.load(npy_path2)

print_stats = 0
if print_stats:
    print("Int8_img1")
    print(f"Matrix shape: {arr.shape}")
    print(f"Width (columns): {arr.shape[1] if arr.ndim >= 2 else 'N/A'}")
    print(f"Height (rows): {arr.shape[0]}")
    print(f"Data type: {arr.dtype}")
    print(f"Min value: {arr.min()}")
    print(f"Max value: {arr.max()}")

    print("Int8_img2")
    print(f"Matrix shape: {arr2.shape}")
    print(f"Width (columns): {arr2.shape[1] if arr2.ndim >= 2 else 'N/A'}")
    print(f"Height (rows): {arr2.shape[0]}")
    print(f"Data type: {arr2.dtype}")
    print(f"Min value: {arr2.min()}")
    print(f"Max value: {arr2.max()}")

# plt.figure(figsize=(8,4))
# plt.imshow(arr, cmap="gray", origin="lower")
# plt.title("Input matrix (int8)")
# plt.axis("off")

plt.imshow(arr, aspect='auto', cmap='viridis', origin='lower')
plt.title("Spectrogram Image from NPY Matrix")
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(label='Intensity')
plt.show()

plt.imshow(arr2, aspect='auto', cmap='viridis', origin='lower')
plt.title("Spectrogram Image from NPY Matrix")
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(label='Intensity')
plt.show()
# Out:
# Float64
# Matrix shape: (128, 873)
# Width (columns): 873
# Height (rows): 128
# Data type: float64
# Data type: float64
# Min value: 1.614017782269791e-12
# Max value: 1.1831829324599633e-07
#
# Int8
# Matrix shape: (128, 873)
# Width (columns): 873
# Height (rows): 128
# Data type: int8
# Min value: -128
# Max value: 127
