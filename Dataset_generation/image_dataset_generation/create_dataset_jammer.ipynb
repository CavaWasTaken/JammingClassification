# %%
from signal_analysis import SignalAnalysis
import os
import numpy as np
import pandas as pd

# %% [markdown]
# **Connection to Google Drive**
# - Locally: use rclone to mount Google Drive to a local folder
# - Google Colab

# %%
from google.colab import drive, files
drive.mount('/content/drive')
data_path = '/content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi'
# Out:
# Mounted at /content/drive

# %%
# Unmount if already mounted, then mount with proper caching
# !fusermount -u ~/GoogleDrive 2>/dev/null || true
# !rclone mount gdrive: ~/GoogleDrive --vfs-cache-mode full --daemon --vfs-read-chunk-size 128M --buffer-size 128M

data_path = '/home/cavallinux/GoogleDrive/N-MON/Dataset_LINKS_preso_da_noi'
# Out:
# Fatal error: directory already mounted, use --allow-non-empty to mount anyway: /home/cavallinux/GoogleDrive

# %% [markdown]
# **Environment Setup**

# %%
# Input file details
# __basedir__ = os.path.abspath("../..")
# path_of_file = os.path.join(__basedir__, 'IQ_DATA') # Path to the folder containing IQ files
fs_ = 10e6  # Sampling frequency
fc_ = 1575.42e6 # Carrier frequency
output_type_ = "fc32"    # Output type of the file - float32
chunk_separation_file = 100e-3  # Chunk separation in seconds (100 ms) - if we want to increase the amount of read data increase this value
skip_second = 5  # Seconds to skip at the beginning of the file
type_to_do = ['LN']  # 'LWF', 'LN', 'TICK', 'TRI', 'TRIW'

# %% [markdown]
# **Folder Structure**

# %%
jammer_folder = [os.path.join(data_path, f) for f in os.listdir(data_path)]
jammer_folder
# Out:
# ['/content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_112953_LWF',
#  '/content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_115231_LN',
#  '/content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_135534_TICK',
#  '/content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_142018_TRI',
#  '/content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_154305_TRIW',
#  '/content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_160202_CLEAN',
#  '/content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/Observation_N_MON.zip',
#  '/content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260304_163557_CLEAN_antennina']

# %% [markdown]
# **Test Data Access**

# %%
# Test if rclone mount supports offset reads properly
test_file = jammer_folder[0] if jammer_folder else None
if test_file:
    print(f"Testing file access: {test_file}")

    # Test 1: Basic read from start
    try:
        data = np.fromfile(test_file, dtype=np.complex64, count=10)
        print(f"✓ Basic read from start: {data.shape}")
    except Exception as e:
        print(f"✗ Basic read failed: {e}")

    # Test 2: Read with offset using np.fromfile
    try:
        data = np.fromfile(test_file, dtype=np.complex64, offset=1000, count=10)
        print(f"✓ Read with offset (np.fromfile): {data.shape}")
    except Exception as e:
        print(f"✗ Read with offset failed: {e}")

    # Test 3: Manual seek and read (alternative approach)
    try:
        with open(test_file, 'rb') as f:
            f.seek(1000)
            data = np.fromfile(f, dtype=np.complex64, count=10)
        print(f"✓ Manual seek then read: {data.shape}")
    except Exception as e:
        print(f"✗ Manual seek failed: {e}")

    # Test 4: Read with large offset (like in your actual code)
    try:
        data = np.fromfile(test_file, dtype=np.complex64, offset=400000000, count=1000)
        print(f"✓ Read with large offset (400MB): {data.shape}")
    except Exception as e:
        print(f"✗ Read with large offset failed: {e}")
# Out:
# Testing file access: /content/drive/MyDrive/N-MON/Dataset_LINKS/LINKS_L1_10Mhz_complex_int8_20251202_112953_LWF
# ✓ Basic read from start: (10,)
# ✓ Read with offset (np.fromfile): (10,)
# ✓ Manual seek then read: (10,)
# ✓ Read with large offset (400MB): (1000,)

# %% [markdown]
# **Data processing of P1, P2, P3, P4**

# %%
for jammer_path in jammer_folder:
    interference_type = jammer_path.split('_')[-1]  # extract the jamming type from the folder name
    if interference_type not in type_to_do: # skip if the interference type is not the same that we want to process
        continue
    print(f"Processing interference type: {interference_type}")

    #Create Columns
    features_name = [f'f{i}' for i in range(1, 17)] + ['power', 'path_spec', 'class']
    rows = []

    # dataset_output
    base_output_dir = os.path.join('./', 'image_dataset', interference_type)    # base output directory
    base_array_dir = os.path.join('./', 'array_dataset', interference_type)    # numpy array output directory
    # os.makedirs(base_output_dir, exist_ok=True) # create the output directory if it does not exist
    # os.makedirs(base_array_dir, exist_ok=True) # create array directory

    file_size = os.path.getsize(jammer_path)    # get the size of the file
    total_sec = round(file_size / fs_ / {'fc32': 8, 'sc16': 4, 'sc8': 2}[output_type_]) # calculate the total duration of the file in seconds

    print(f'File size: {file_size:,} bytes')
    print(f'Total seconds for {jammer_path}: {total_sec} ({total_sec/60:.1f} minutes)')

    signal_analysis_object = SignalAnalysis(fs=fs_, fc=fc_, output_type=output_type_, file_name=jammer_path)    # create the SignalAnalysis object

    # MAIN LOOP for creating dataset
    # Each jamming file contains 8 different power levels. Each power level lasts 2 minutes (120 seconds)
    # For each power level: skip first 5 seconds and last 5 seconds, process the middle 110 seconds
    power_duration = 120  # seconds per power level
    valid_duration_per_power = power_duration - 2 * skip_second  # 110 seconds of valid data per power level
    num_power_levels = 8

    for power_idx in range(int(num_power_levels/2)):
        jammer_power = f"P{power_idx + 1}"  # P1, P2, P3, P4
        power_dir = os.path.join(base_array_dir, f"{jammer_power}")
        # os.makedirs(power_dir, exist_ok=True)

        # Calculate time range for this power level
        power_start = power_idx * power_duration + skip_second  # Skip first 5 seconds
        power_end = (power_idx + 1) * power_duration - skip_second  # Skip last 5 seconds

        # Make sure we don't exceed file duration
        if power_start >= total_sec:
            print(f"Skipping power level {jammer_power} - beyond file duration")
            break
        if power_end > total_sec:
            power_end = total_sec

        print(f"Processing {jammer_power}: from {power_start}s to {power_end}s ({power_end - power_start:.1f}s)")

        # Process chunks within this power level
        loop_range = np.arange(power_start, power_end, chunk_separation_file)
        print(f"  Will process {len(loop_range)} chunks for {jammer_power}")

        try:
            for i, start_point_file in enumerate(loop_range):
                # file_name_img = os.path.join(base_output_dir, f"{jammer_power}_{i}.jpg")
                # spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
                file_name_npy = os.path.join(power_dir, f"{jammer_power}_{i}.npy")
                # np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array

                features_signal = signal_analysis_object.extract_features(start_point=start_point_file)
                rows.append(features_signal + [jammer_power, file_name_npy, interference_type])

                # print(f"  Saved {file_name_npy}")
                print(f"  {jammer_power}: Processed chunk {i+1}/{len(loop_range)}")

            print(f"  {jammer_power}: Completed {len(loop_range)} chunks                    ")

        except Exception as e:
            print(f"\nERROR in {jammer_power} at chunk {i}: {str(e)}")
            import traceback
            traceback.print_exc()
            print("Continuing to next power level...")
            continue

    print(f"\nTotal rows collected: {len(rows)}")
    df = pd.DataFrame(rows, columns=features_name)
    output_csv_path = os.path.join('./', f'features_file_{interference_type}_1.csv')
    df.to_csv(output_csv_path, sep=',')
    print(f"Completed {interference_type}, saved to {output_csv_path}")
# Out:
# Processing interference type: LN
# File size: 76,742,146,464 bytes
# Total seconds for /content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_
#   P1: Processed chunk 552/1100
#   P1: Processed chunk 553/1100
#   P1: Processed chunk 554/1100
#   P1: Processed chunk 555/1100
#   P1: Processed chunk 556/1100
#   P1: Processed chunk 557/1100
#   P1: Processed chunk 558/1100
#   P1: Processed chunk 559/1100
#   P1: Processed chunk 560/1100
#   P1: Processed chunk 561/1100
#   P1: Processed chunk 562/1100
#   P1: Processed chunk 563/1100
#   P1: Processed chunk 564/1100
#   P1: Processed chunk 565/1100
#   P1: Processed chunk 566/1100
#   P1: Processed chunk 567/1100
#   P1: Processed chunk 568/1100
#   P1: Processed chunk 569/1100
#   P1: Processed chunk 570/1100
#   P1: Processed chunk 571/1100
#   P1: Processed chunk 572/1100
#   P1: Processed chunk 573/1100
#   P1: Processed chunk 574/1100
#   P1: Processed chunk 575/1100
#   P1: Processed chunk 576/1100
#   P1: Processed chunk 577/1100
#   P1: Processed chunk 578/1100
#   P1: Processed chunk 579/1100
#   P1: Processed chunk 580/1100
#   P1: Processed chunk 581/1100
#   P1: Processed chunk 582/1100
#   P1: Processed chunk 583/1100
#   P1: Processed chunk 584/1100
#   P1: Processed chunk 585/1100
#   P1: Processed chunk 586/1100
#   P1: Processed chunk 587/1100
#   P1: Processed chunk 588/1100
#   P1: Processed chunk 589/1100
#   P1: Processed chunk 590/1100
#   P1: Processed chunk 591/1100
#   P1: Processed chunk 592/1100
#   P1: Processed chunk 593/1100
#   P1: Processed chunk 594/1100
#   P1: Processed chunk 595/1100
#   P1: Processed chunk 596/1100

# %%
# download the folder array_dataset
# !zip -r array_dataset1.zip ./array_dataset
files.download(f"features_file_{type_to_do}_1.csv")

# %%
# clean the array_dataset folder from Colab
import shutil
shutil.rmtree('./array_dataset')

# %% [markdown]
# **Data Processing of P5, P6, P7, P8**

# %%
for jammer_path in jammer_folder:
    interference_type = jammer_path.split('_')[-1]  # extract the jamming type from the folder name
    if interference_type not in type_to_do: # skip if the interference type is not the same that we want to process
        continue
    print(f"Processing interference type: {interference_type}")

    #Create Columns
    features_name = [f'f{i}' for i in range(1, 17)] + ['power', 'path_spec', 'class']
    rows = []

    # dataset_output
    base_output_dir = os.path.join('./', 'image_dataset', interference_type)    # base output directory
    base_array_dir = os.path.join('./', 'array_dataset', interference_type)    # numpy array output directory
    # os.makedirs(base_output_dir, exist_ok=True) # create the output directory if it does not exist
    # os.makedirs(base_array_dir, exist_ok=True) # create array directory

    file_size = os.path.getsize(jammer_path)    # get the size of the file
    total_sec = round(file_size / fs_ / {'fc32': 8, 'sc16': 4, 'sc8': 2}[output_type_]) # calculate the total duration of the file in seconds

    print(f'File size: {file_size:,} bytes')
    print(f'Total seconds for {jammer_path}: {total_sec} ({total_sec/60:.1f} minutes)')

    signal_analysis_object = SignalAnalysis(fs=fs_, fc=fc_, output_type=output_type_, file_name=jammer_path)    # create the SignalAnalysis object

    # MAIN LOOP for creating dataset
    # Each jamming file contains 8 different power levels. Each power level lasts 2 minutes (120 seconds)
    # For each power level: skip first 5 seconds and last 5 seconds, process the middle 110 seconds
    power_duration = 120  # seconds per power level
    valid_duration_per_power = power_duration - 2 * skip_second  # 110 seconds of valid data per power level
    num_power_levels = 8

    for power_idx in range(int(num_power_levels/2)):
        power_idx += 4
        jammer_power = f"P{power_idx + 1}"  # P5, P6, P7, P8
        power_dir = os.path.join(base_array_dir, f"{jammer_power}")
        # os.makedirs(power_dir, exist_ok=True)

        # Calculate time range for this power level
        power_start = power_idx * power_duration + skip_second  # Skip first 5 seconds
        power_end = (power_idx + 1) * power_duration - skip_second  # Skip last 5 seconds

        # Make sure we don't exceed file duration
        if power_start >= total_sec:
            print(f"Skipping power level {jammer_power} - beyond file duration")
            break
        if power_end > total_sec:
            power_end = total_sec

        print(f"Processing {jammer_power}: from {power_start}s to {power_end}s ({power_end - power_start:.1f}s)")

        # Process chunks within this power level
        loop_range = np.arange(power_start, power_end, chunk_separation_file)
        print(f"  Will process {len(loop_range)} chunks for {jammer_power}")

        try:
            for i, start_point_file in enumerate(loop_range):
                # file_name_img = os.path.join(base_output_dir, f"{jammer_power}_{i}.jpg")
                # spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
                file_name_npy = os.path.join(power_dir, f"{jammer_power}_{i}.npy")
                # np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array

                features_signal = signal_analysis_object.extract_features(start_point=start_point_file)
                rows.append(features_signal + [jammer_power, file_name_npy, interference_type])

                # print(f"  Saved {file_name_npy}")

                print(f"  {jammer_power}: Processed chunk {i+1}/{len(loop_range)}")

            print(f"  {jammer_power}: Completed {len(loop_range)} chunks                    ")

        except Exception as e:
            print(f"\nERROR in {jammer_power} at chunk {i}: {str(e)}")
            import traceback
            traceback.print_exc()
            print("Continuing to next power level...")
            continue

    print(f"\nTotal rows collected: {len(rows)}")
    df = pd.DataFrame(rows, columns=features_name)
    output_csv_path = os.path.join('./', f'features_file_{interference_type}_2.csv')
    df.to_csv(output_csv_path, sep=',')
    print(f"Completed {interference_type}, saved to {output_csv_path}")

# %%
# download the folder array_dataset
# !zip -r array_dataset2.zip ./image_dataset/CLEAN/
files.download(f"features_file_{type_to_do}_2.csv")

# %%
import shutil
shutil.rmtree('./array_dataset')

# %% [markdown]
# **Data Processing of CLEAN data**

# %%
for jammer_path in jammer_folder:
    interference_type = jammer_path.split('_')[-1]  # extract the jamming type from the folder name
    if interference_type not in type_to_do: # skip if the interference type is not the same that we want to process
        continue
    print(f"Processing interference type: {interference_type}")

    #Create Columns
    features_name = [f'f{i}' for i in range(1, 17)] + ['path_spec', 'class']
    rows = []

    # dataset_output
    base_output_dir = os.path.join('./', 'image_dataset', interference_type)    # base output directory
    base_array_dir = os.path.join('./', 'array_dataset', interference_type)    # numpy array output directory
    # os.makedirs(base_output_dir, exist_ok=True) # create the output directory if it does not exist
    # os.makedirs(base_array_dir, exist_ok=True) # create array directory

    file_size = os.path.getsize(jammer_path)    # get the size of the file
    total_sec = round(file_size / fs_ / {'fc32': 8, 'sc16': 4, 'sc8': 2}[output_type_]) # calculate the total duration of the file in seconds

    print(f'File size: {file_size:,} bytes')
    print(f'Total seconds for {jammer_path}: {total_sec} ({total_sec/60:.1f} minutes)')

    signal_analysis_object = SignalAnalysis(fs=fs_, fc=fc_, output_type=output_type_, file_name=jammer_path)    # create the SignalAnalysis object

    # Calculate time range for this power level
    start = skip_second  # Skip first 5 seconds
    end = total_sec - skip_second  # Skip last 5 seconds

    # Process chunks within this power level
    loop_range = np.arange(start, end, chunk_separation_file)
    print(f"  Will process {len(loop_range)} chunks for {interference_type}")

    try:
        for i, start_point_file in enumerate(loop_range):
            # file_name_img = os.path.join(base_output_dir, f"{i}.jpg")
            # spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
            file_name_npy = os.path.join(base_array_dir, f"{i}.npy")
            # np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array

            features_signal = signal_analysis_object.extract_features(start_point=start_point_file)
            rows.append(features_signal + [file_name_npy, interference_type])

            # print(f"  Saved {file_name_npy}")

            print(f"  Processed chunk {i+1}/{len(loop_range)}")

        print(f"  Completed {len(loop_range)} chunks                    ")

    except Exception as e:
        print(f"\nERROR in {jammer_power} at chunk {i}: {str(e)}")
        import traceback
        traceback.print_exc()
        print("Continuing to next power level...")
        continue

    print(f"\nTotal rows collected: {len(rows)}")
    df = pd.DataFrame(rows, columns=features_name)
    output_csv_path = os.path.join('./', f'features_file_{interference_type}.csv')
    df.to_csv(output_csv_path, sep=',')
    print(f"Completed {interference_type}, saved to {output_csv_path}")
# Out:
# Processing interference type: antennina
# File size: 29,047,684,616 bytes
# Total seconds for /content/drive/MyDrive/N-MON/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260304_163557_CLEAN_antennina: 363 (6.0 minutes)
#   Will process 3530 chunks for antennina
# Using memory-mapped file access for LINKS_L1_10Mhz_complex_int8_20260304_163557_CLEAN_antennina
#   Saved ./array_dataset/antennina/0.npy
#   Saved ./array_dataset/antennina/1.npy
#   Saved ./array_dataset/antennina/2.npy
#   Saved ./array_dataset/antennina/3.npy
#   Saved ./array_dataset/antennina/4.npy
#   Saved ./array_dataset/antennina/5.npy
#   Saved ./array_dataset/antennina/6.npy
#   Saved ./array_dataset/antennina/7.npy
#   Saved ./array_dataset/antennina/8.npy
#   Saved ./array_dataset/antennina/9.npy
#   Saved ./array_dataset/antennina/10.npy
#   Saved ./array_dataset/antennina/11.npy
#   Saved ./array_dataset/antennina/12.npy
#   Saved ./array_dataset/antennina/13.npy
#   Saved ./array_dataset/antennina/14.npy
#   Saved ./array_dataset/antennina/15.npy
#   Saved ./array_dataset/antennina/16.npy
#   Saved ./array_dataset/antennina/17.npy
#   Saved ./array_dataset/antennina/18.npy
#   Saved ./array_dataset/antennina/19.npy
#   Saved ./array_dataset/antennina/20.npy
#   Saved ./array_dataset/antennina/21.npy
#   Saved ./array_dataset/antennina/22.npy
#   Saved ./array_dataset/antennina/23.npy
#   Saved ./array_dataset/antennina/24.npy
#   Saved ./array_dataset/antennina/25.npy
#   Saved ./array_dataset/antennina/26.npy
#   Saved ./array_dataset/antennina/27.npy
#   Saved ./array_dataset/antennina/28.npy
#   Saved ./array_dataset/antennina/29.npy
#   Saved ./array_dataset/antennina/30.npy
#   Saved ./array_dataset/antennina/31.npy
#   Saved ./array_dataset/antennina/32.npy
#   Saved ./array_dataset/antennina/33.npy
#   Saved ./array_dataset/antennina/34.npy
#   Saved ./array_dataset/antennina/35.npy
#   Saved ./array_dataset/antennina/36.npy
#   Saved ./array_dataset/antennina/37.npy
#   Saved ./array_dataset/antennina/38.npy
#   Saved ./array_dataset/antennina/39.npy
#   Saved ./array_dataset/antennina/40.npy
#   Saved ./array_dataset/antennina/41.npy
#   Saved ./array_dataset/antennina/42.npy
#   Saved ./array_dataset/antennina/43.npy
#   Saved ./array_dataset/antennina/44.npy
#   Saved ./array_dataset/antennina/45.npy
#   Saved ./array_dataset/antennina/46.npy
#   Saved ./array_dataset/antennina/47.npy
#   Saved ./array_dataset/antennina/48.npy
#   Saved ./array_dataset/antennina/49.npy
#   Saved ./array_dataset/antennina/50.npy
#   Saved ./array_dataset/antennina/51.npy
#   Saved ./array_dataset/antennina/52.npy
#   Saved ./array_dataset/antennina/53.npy
#   Saved ./array_dataset/antennina/54.npy
#   Saved ./array_dataset/antennina/55.npy
#   Saved ./array_dataset/antennina/56.npy
#   Saved ./array_dataset/antennina/57.npy
#   Saved ./array_dataset/antennina/58.npy
#   Saved ./array_dataset/antennina/59.npy
#   Saved ./array_dataset/antennina/60.npy
#   Saved ./array_dataset/antennina/61.npy
#   Saved ./array_dataset/antennina/62.npy
#   Saved ./array_dataset/antennina/63.npy
#   Saved ./array_dataset/antennina/64.npy
#   Saved ./array_dataset/antennina/65.npy
#   Saved ./array_dataset/antennina/66.npy
#   Saved ./array_dataset/antennina/67.npy
#   Saved ./array_dataset/antennina/68.npy
#   Saved ./array_dataset/antennina/69.npy
#   Saved ./array_dataset/antennina/70.npy
#   Saved ./array_dataset/antennina/71.npy
#   Saved ./array_dataset/antennina/72.npy
#   Saved ./array_dataset/antennina/73.npy
#   Saved ./array_dataset/antennina/74.npy
#   Saved ./array_dataset/antennina/75.npy
#   Saved ./array_dataset/antennina/76.npy
#   Saved ./array_dataset/antennina/77.npy
#   Saved ./array_dataset/antennina/78.npy
#   Saved ./array_dataset/antennina/79.npy
#   Saved ./array_dataset/antennina/80.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_186/568542485.py in <cell line: 0>()
#      34         for i, start_point_file in enumerate(loop_range):
#      35             file_name_img = os.path.join(base_output_dir, f"{i}.jpg")
# ---> 36             spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
#      37             file_name_npy = os.path.join(base_array_dir, f"{i}.npy")
#      38             np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array
#
# /content/signal_analysis.py in spectrogram_image(self, start_point, window_interval, nfft, window, overlap_percentage)
#     123
#     124         if self.file_name is not None:
# --> 125             raw_signal_ = self.read_bin_file(window_interval, start_point)
#     126             # print(raw_signal_.shape)
#     127             if overlap_percentage is not None:
#
# /content/signal_analysis.py in read_bin_file(self, window_interval, start_point)
#      80             if self.output_type == "fc32":
#      81                 offset_ = int(start_point * self.fs)    # offset in number of complex samples (not bytes)
# ---> 82                 raw_signal = memmap[offset_: offset_ + num_samples].copy()  # read complex64 samples without loading entire file
#      83
#      84             elif self.output_type == "sc16":
#
# KeyboardInterrupt:

# %%
# download the folder array_dataset
# !zip -r array_dataset2.zip ./image_dataset/CLEAN/
files.download(f"features_file_{type_to_do}.csv")
