# %%
from signal_analysis import SignalAnalysis
import os
import numpy as np
import pandas as pd

# %% [markdown]
# **Connection to Google Drive**
# - Locally: use rclone to mount Google Drive to a local folder
# - Google Colab

# %%
from google.colab import drive, files
drive.mount('/content/drive')
data_path = '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi'
# Out:
# Mounted at /content/drive

# %%
# # Unmount if already mounted, then mount with proper caching
# # !fusermount -u ~/GoogleDrive 2>/dev/null || true
# !rclone mount gdrive: ~/GoogleDrive --vfs-cache-mode full --daemon --vfs-read-chunk-size 128M --buffer-size 128M

# data_path = '/home/cavallinux/GoogleDrive/N-MON/Dataset_LINKS_preso_da_noi'
# Out:
# Fatal error: directory already mounted, use --allow-non-empty to mount anyway: /home/cavallinux/GoogleDrive

# %% [markdown]
# **Environment Setup**

# %%
# Input file details
# __basedir__ = os.path.abspath("../..")
# path_of_file = os.path.join(__basedir__, 'IQ_DATA') # Path to the folder containing IQ files
fs_ = 10e6  # Sampling frequency
fc_ = 1575.42e6 # Carrier frequency
output_type_ = "fc32"    # Output type of the file - float32
chunk_separation_file = 100e-3  # Chunk separation in seconds (100 ms) - if we want to increase the amount of read data increase this value
skip_second = 5  # Seconds to skip at the beginning of the file
type_to_do = ['antennina2']  # 'LWF', 'LN', 'TICK', 'TRI', 'TRIW'

# %% [markdown]
# **Folder Structure**

# %%
jammer_folder = [os.path.join(data_path, f) for f in os.listdir(data_path)]
jammer_folder
# Out:
# ['/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_112953_LWF',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_115231_LN',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_135534_TICK',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_142018_TRI',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_154305_TRIW',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20251202_160202_CLEAN',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/Observation_N_MON.zip',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260304_163557_CLEAN_antennina',
#  '/content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260310_180247_CLEAN_antennina2']

# %% [markdown]
# **Test Data Access**

# %%
# Test if rclone mount supports offset reads properly
test_file = jammer_folder[0] if jammer_folder else None
if test_file:
    print(f"Testing file access: {test_file}")

    # Test 1: Basic read from start
    try:
        data = np.fromfile(test_file, dtype=np.complex64, count=10)
        print(f"✓ Basic read from start: {data.shape}")
    except Exception as e:
        print(f"✗ Basic read failed: {e}")

    # Test 2: Read with offset using np.fromfile
    try:
        data = np.fromfile(test_file, dtype=np.complex64, offset=1000, count=10)
        print(f"✓ Read with offset (np.fromfile): {data.shape}")
    except Exception as e:
        print(f"✗ Read with offset failed: {e}")

    # Test 3: Manual seek and read (alternative approach)
    try:
        with open(test_file, 'rb') as f:
            f.seek(1000)
            data = np.fromfile(f, dtype=np.complex64, count=10)
        print(f"✓ Manual seek then read: {data.shape}")
    except Exception as e:
        print(f"✗ Manual seek failed: {e}")

    # Test 4: Read with large offset (like in your actual code)
    try:
        data = np.fromfile(test_file, dtype=np.complex64, offset=400000000, count=1000)
        print(f"✓ Read with large offset (400MB): {data.shape}")
    except Exception as e:
        print(f"✗ Read with large offset failed: {e}")
# Out:
# Testing file access: /content/drive/MyDrive/N-MON/Dataset_LINKS/LINKS_L1_10Mhz_complex_int8_20251202_112953_LWF
# ✓ Basic read from start: (10,)
# ✓ Read with offset (np.fromfile): (10,)
# ✓ Manual seek then read: (10,)
# ✓ Read with large offset (400MB): (1000,)

# %% [markdown]
# **Data processing of P1, P2, P3, P4**

# %%
for jammer_path in jammer_folder:
    interference_type = jammer_path.split('_')[-1]  # extract the jamming type from the folder name
    if interference_type not in type_to_do: # skip if the interference type is not the same that we want to process
        continue
    print(f"Processing interference type: {interference_type}")

    #Create Columns
    features_name = [f'f{i}' for i in range(1, 17)] + ['power', 'path_spec', 'class']
    rows = []

    drive_output_root = '/content/drive/MyDrive/N-MON/ALTRO/array_dataset'
    drive_csv_dir = '/content/drive/MyDrive/N-MON/ALTRO/features_csv'

    base_array_dir = os.path.join(drive_output_root, interference_type)
    os.makedirs(base_array_dir, exist_ok=True)
    os.makedirs(drive_csv_dir, exist_ok=True)

    file_size = os.path.getsize(jammer_path)    # get the size of the file
    total_sec = round(file_size / fs_ / {'fc32': 8, 'sc16': 4, 'sc8': 2}[output_type_]) # calculate the total duration of the file in seconds

    print(f'File size: {file_size:,} bytes')
    print(f'Total seconds for {jammer_path}: {total_sec} ({total_sec/60:.1f} minutes)')

    signal_analysis_object = SignalAnalysis(fs=fs_, fc=fc_, output_type=output_type_, file_name=jammer_path)    # create the SignalAnalysis object

    # MAIN LOOP for creating dataset
    # Each jamming file contains 8 different power levels. Each power level lasts 2 minutes (120 seconds)
    # For each power level: skip first 5 seconds and last 5 seconds, process the middle 110 seconds
    power_duration = 120  # seconds per power level
    valid_duration_per_power = power_duration - 2 * skip_second  # 110 seconds of valid data per power level
    num_power_levels = 8

    for power_idx in range(int(num_power_levels/2)):
        jammer_power = f"P{power_idx + 1}"  # P1, P2, P3, P4
        power_dir = os.path.join(base_array_dir, f"{jammer_power}")
        os.makedirs(power_dir, exist_ok=True)

        # Calculate time range for this power level
        power_start = power_idx * power_duration + skip_second  # Skip first 5 seconds
        power_end = (power_idx + 1) * power_duration - skip_second  # Skip last 5 seconds

        # Make sure we don't exceed file duration
        if power_start >= total_sec:
            print(f"Skipping power level {jammer_power} - beyond file duration")
            break
        if power_end > total_sec:
            power_end = total_sec

        print(f"Processing {jammer_power}: from {power_start}s to {power_end}s ({power_end - power_start:.1f}s)")

        # Process chunks within this power level
        loop_range = np.arange(power_start, power_end, chunk_separation_file)
        print(f"  Will process {len(loop_range)} chunks for {jammer_power}")

        try:
            for i, start_point_file in enumerate(loop_range):
                spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
                file_name_npy = os.path.join(power_dir, f"{jammer_power}_{i}.npy")
                np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array

                features_signal = signal_analysis_object.extract_features(start_point=start_point_file)
                rows.append(features_signal + [jammer_power, file_name_npy, interference_type])

                print(f"  Saved {file_name_npy}")
                print(f"  {jammer_power}: Processed chunk {i+1}/{len(loop_range)}")

            print(f"  {jammer_power}: Completed {len(loop_range)} chunks                    ")

        except Exception as e:
            print(f"\nERROR in {jammer_power} at chunk {i}: {str(e)}")
            import traceback
            traceback.print_exc()
            print("Continuing to next power level...")
            continue

    print(f"\nTotal rows collected: {len(rows)}")
    df = pd.DataFrame(rows, columns=features_name)
    output_csv_path = os.path.join(drive_csv_dir, f'features_file_{interference_type}_1.csv')
    df.to_csv(output_csv_path, sep=',')
    print(f"Completed {interference_type}, saved to {output_csv_path}")
# Out:
# Processing interference type: antennina2
# File size: 25,424,826,936 bytes
# Total seconds for /content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260310_180247_CLEAN_antennina2: 318 (5.3 minutes)
# Processing P1: from 5s to 115s (110.0s)
#   Will process 1100 chunks for P1
# Using memory-mapped file access for LINKS_L1_10Mhz_complex_int8_20260310_180247_CLEAN_antennina2
#
# ERROR in P1 at chunk 0: [Errno 2] No such file or directory: './array_dataset/antennina2/P1/P1_0.npy'
# Continuing to next power level...
# Processing P2: from 125s to 235s (110.0s)
#   Will process 1100 chunks for P2
# Traceback (most recent call last):
#   File "/tmp/ipykernel_395/2225114963.py", line 59, in <cell line: 0>
#     np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 570, in save
#     file_ctx = open(file, "wb")
#                ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './array_dataset/antennina2/P1/P1_0.npy'
# ERROR in P2 at chunk 0: [Errno 2] No such file or directory: './array_dataset/antennina2/P2/P2_0.npy'
# Continuing to next power level...
# Processing P3: from 245s to 318s (73.0s)
#   Will process 730 chunks for P3
# Traceback (most recent call last):
#   File "/tmp/ipykernel_395/2225114963.py", line 59, in <cell line: 0>
#     np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 570, in save
#     file_ctx = open(file, "wb")
#                ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './array_dataset/antennina2/P2/P2_0.npy'
# ERROR in P3 at chunk 0: [Errno 2] No such file or directory: './array_dataset/antennina2/P3/P3_0.npy'
# Continuing to next power level...
# Skipping power level P4 - beyond file duration
#
# Total rows collected: 0
# Completed antennina2, saved to ./features_file_antennina2_1.csv
# Traceback (most recent call last):
#   File "/tmp/ipykernel_395/2225114963.py", line 59, in <cell line: 0>
#     np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 570, in save
#     file_ctx = open(file, "wb")
#                ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './array_dataset/antennina2/P3/P3_0.npy'

# %%
# download the folder array_dataset
# !zip -r array_dataset1.zip ./array_dataset
files.download(f"features_file_{type_to_do}_1.csv")

# %%
# clean the array_dataset folder from Colab
import shutil
shutil.rmtree('./array_dataset')

# %% [markdown]
# **Data Processing of P5, P6, P7, P8**

# %%
for jammer_path in jammer_folder:
    interference_type = jammer_path.split('_')[-1]  # extract the jamming type from the folder name
    if interference_type not in type_to_do: # skip if the interference type is not the same that we want to process
        continue
    print(f"Processing interference type: {interference_type}")

    #Create Columns
    features_name = [f'f{i}' for i in range(1, 17)] + ['power', 'path_spec', 'class']
    rows = []

    drive_output_root = '/content/drive/MyDrive/N-MON/ALTRO/array_dataset'
    drive_csv_dir = '/content/drive/MyDrive/N-MON/ALTRO/features_csv'

    base_array_dir = os.path.join(drive_output_root, interference_type)
    os.makedirs(base_array_dir, exist_ok=True)
    os.makedirs(drive_csv_dir, exist_ok=True)

    file_size = os.path.getsize(jammer_path)    # get the size of the file
    total_sec = round(file_size / fs_ / {'fc32': 8, 'sc16': 4, 'sc8': 2}[output_type_]) # calculate the total duration of the file in seconds

    print(f'File size: {file_size:,} bytes')
    print(f'Total seconds for {jammer_path}: {total_sec} ({total_sec/60:.1f} minutes)')

    signal_analysis_object = SignalAnalysis(fs=fs_, fc=fc_, output_type=output_type_, file_name=jammer_path)    # create the SignalAnalysis object

    # MAIN LOOP for creating dataset
    # Each jamming file contains 8 different power levels. Each power level lasts 2 minutes (120 seconds)
    # For each power level: skip first 5 seconds and last 5 seconds, process the middle 110 seconds
    power_duration = 120  # seconds per power level
    valid_duration_per_power = power_duration - 2 * skip_second  # 110 seconds of valid data per power level
    num_power_levels = 8

    for power_idx in range(int(num_power_levels/2)):
        power_idx += 4
        jammer_power = f"P{power_idx + 1}"  # P5, P6, P7, P8
        power_dir = os.path.join(base_array_dir, f"{jammer_power}")
        os.makedirs(power_dir, exist_ok=True)

        # Calculate time range for this power level
        power_start = power_idx * power_duration + skip_second  # Skip first 5 seconds
        power_end = (power_idx + 1) * power_duration - skip_second  # Skip last 5 seconds

        # Make sure we don't exceed file duration
        if power_start >= total_sec:
            print(f"Skipping power level {jammer_power} - beyond file duration")
            break
        if power_end > total_sec:
            power_end = total_sec

        print(f"Processing {jammer_power}: from {power_start}s to {power_end}s ({power_end - power_start:.1f}s)")

        # Process chunks within this power level
        loop_range = np.arange(power_start, power_end, chunk_separation_file)
        print(f"  Will process {len(loop_range)} chunks for {jammer_power}")

        try:
            for i, start_point_file in enumerate(loop_range):
                spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
                file_name_npy = os.path.join(power_dir, f"{jammer_power}_{i}.npy")
                np.save(file_name_npy, spec_array)  # Saves as (128, 873) uint8 array

                features_signal = signal_analysis_object.extract_features(start_point=start_point_file)
                rows.append(features_signal + [jammer_power, file_name_npy, interference_type])

                print(f"  Saved {file_name_npy}")

                print(f"  {jammer_power}: Processed chunk {i+1}/{len(loop_range)}")

            print(f"  {jammer_power}: Completed {len(loop_range)} chunks                    ")

        except Exception as e:
            print(f"\nERROR in {jammer_power} at chunk {i}: {str(e)}")
            import traceback
            traceback.print_exc()
            print("Continuing to next power level...")
            continue

    print(f"\nTotal rows collected: {len(rows)}")
    df = pd.DataFrame(rows, columns=features_name)
    output_csv_path = os.path.join(drive_csv_dir, f'features_file_{interference_type}_2.csv')
    df.to_csv(output_csv_path, sep=',')
    print(f"Completed {interference_type}, saved to {output_csv_path}")

# %%
# download the folder array_dataset
# !zip -r array_dataset2.zip ./image_dataset/CLEAN/
files.download(f"features_file_{type_to_do}_2.csv")

# %%
import shutil
shutil.rmtree('./array_dataset')

# %% [markdown]
# **Data Processing of CLEAN data**

# %%
for jammer_path in jammer_folder:
    interference_type = os.path.basename(jammer_path).split('_')[-1]  # extract jamming type from filename
    if interference_type not in type_to_do:  # skip if not in selected types
        continue
    print(f"Processing interference type: {interference_type}")

    # Create Columns
    features_name = [f'f{i}' for i in range(1, 17)] + ['path_spec', 'class']
    rows = []

    # --- DIRECT WRITE TO GOOGLE DRIVE ---
    drive_output_root = '/content/drive/MyDrive/N-MON/ALTRO/array_dataset'
    drive_csv_dir = '/content/drive/MyDrive/N-MON/ALTRO/features_csv'

    base_array_dir = os.path.join(drive_output_root, interference_type)
    os.makedirs(base_array_dir, exist_ok=True)
    os.makedirs(drive_csv_dir, exist_ok=True)

    file_size = os.path.getsize(jammer_path)  # get file size
    total_sec = round(file_size / fs_ / {'fc32': 8, 'sc16': 4, 'sc8': 2}[output_type_])  # total duration in seconds

    print(f'File size: {file_size:,} bytes')
    print(f'Total seconds for {jammer_path}: {total_sec} ({total_sec/60:.1f} minutes)')
    print(f'Writing NPY to: {base_array_dir}')

    signal_analysis_object = SignalAnalysis(
        fs=fs_,
        fc=fc_,
        output_type=output_type_,
        file_name=jammer_path
    )

    # Calculate time range
    start = skip_second
    end = total_sec - skip_second

    # Process chunks
    loop_range = np.arange(start, end, chunk_separation_file)
    print(f"  Will process {len(loop_range)} chunks for {interference_type}")

    try:
        for i, start_point_file in enumerate(loop_range):
            spec_array = signal_analysis_object.spectrogram_image(start_point=start_point_file)
            file_name_npy = os.path.join(base_array_dir, f"{i}.npy")
            np.save(file_name_npy, spec_array)

            features_signal = signal_analysis_object.extract_features(start_point=start_point_file)
            rows.append(features_signal + [file_name_npy, interference_type])

            print(f"  Saved {file_name_npy}")
            print(f"  Processed chunk {i+1}/{len(loop_range)}")

        print(f"  Completed {len(loop_range)} chunks                    ")

    except Exception as e:
        print(f"\nERROR in {interference_type} at chunk {i}: {str(e)}")
        import traceback
        traceback.print_exc()
        print("Continuing to next interference type...")
        continue

    print(f"\nTotal rows collected: {len(rows)}")
    df = pd.DataFrame(rows, columns=features_name)
    output_csv_path = os.path.join(drive_csv_dir, f'features_file_{interference_type}.csv')
    df.to_csv(output_csv_path, sep=',', index=False)
    print(f"Completed {interference_type}, saved to {output_csv_path}")
# Out:
# Processing interference type: antennina2
# File size: 25,424,826,936 bytes
# Total seconds for /content/drive/MyDrive/N-MON/ALTRO/Dataset_LINKS_preso_da_noi/LINKS_L1_10Mhz_complex_int8_20260310_180247_CLEAN_antennina2: 318 (5.3 minutes)
# Writing NPY to: /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2
#   Will process 3080 chunks for antennina2
# Using memory-mapped file access for LINKS_L1_10Mhz_complex_int8_20260310_180247_CLEAN_antennina2
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/0.npy
#   Processed chunk 1/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/1.npy
#   Processed chunk 2/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/2.npy
#   Processed chunk 3/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3.npy
#   Processed chunk 4/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/4.npy
#   Processed chunk 5/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/5.npy
#   Processed chunk 6/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/6.npy
#   Processed chunk 7/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/7.npy
#   Processed chunk 8/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/8.npy
#   Processed chunk 9/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/9.npy
#   Processed chunk 10/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/10.npy
#   Processed chunk 11/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/11.npy
#   Processed chunk 12/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/12.npy
#   Processed chunk 13/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/13.npy
#   Processed chunk 14/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/14.npy
#   Processed chunk 15/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/15.npy
#   Processed chunk 16/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/16.npy
#   Processed chunk 17/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/17.npy
#   Processed chunk 18/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/18.npy
#   Processed chunk 19/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/19.npy
#   Processed chunk 20/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/20.npy
#   Processed chunk 21/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/21.npy
#   Processed chunk 22/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/22.npy
#   Processed chunk 23/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/23.npy
#   Processed chunk 24/3080
# /content/signal_analysis.py:384: RuntimeWarning: divide by zero encountered in log2
#   entropy = np.sum(-normalized_spectrum * np.log2(normalized_spectrum), axis=0)
# /content/signal_analysis.py:384: RuntimeWarning: invalid value encountered in multiply
#   entropy = np.sum(-normalized_spectrum * np.log2(normalized_spectrum), axis=0)
# Output streaming troncato alle ultime 5000 righe.
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/582.npy
#   Processed chunk 583/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/583.npy
#   Processed chunk 584/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/584.npy
#   Processed chunk 585/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/585.npy
#   Processed chunk 586/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/586.npy
#   Processed chunk 587/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/587.npy
#   Processed chunk 588/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/588.npy
#   Processed chunk 589/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/589.npy
#   Processed chunk 590/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/590.npy
#   Processed chunk 591/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/591.npy
#   Processed chunk 592/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/592.npy
#   Processed chunk 593/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/593.npy
#   Processed chunk 594/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/594.npy
#   Processed chunk 595/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/595.npy
#   Processed chunk 596/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/596.npy
#   Processed chunk 597/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/597.npy
#   Processed chunk 598/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/598.npy
#   Processed chunk 599/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/599.npy
#   Processed chunk 600/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/600.npy
#   Processed chunk 601/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/601.npy
#   Processed chunk 602/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/602.npy
#   Processed chunk 603/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/603.npy
#   Processed chunk 604/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/604.npy
#   Processed chunk 605/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/605.npy
#   Processed chunk 606/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/606.npy
#   Processed chunk 607/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/607.npy
#   Processed chunk 608/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2
3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3018.npy
#   Processed chunk 3019/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3019.npy
#   Processed chunk 3020/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3020.npy
#   Processed chunk 3021/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3021.npy
#   Processed chunk 3022/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3022.npy
#   Processed chunk 3023/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3023.npy
#   Processed chunk 3024/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3024.npy
#   Processed chunk 3025/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3025.npy
#   Processed chunk 3026/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3026.npy
#   Processed chunk 3027/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3027.npy
#   Processed chunk 3028/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3028.npy
#   Processed chunk 3029/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3029.npy
#   Processed chunk 3030/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3030.npy
#   Processed chunk 3031/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3031.npy
#   Processed chunk 3032/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3032.npy
#   Processed chunk 3033/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3033.npy
#   Processed chunk 3034/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3034.npy
#   Processed chunk 3035/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3035.npy
#   Processed chunk 3036/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3036.npy
#   Processed chunk 3037/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3037.npy
#   Processed chunk 3038/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3038.npy
#   Processed chunk 3039/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3039.npy
#   Processed chunk 3040/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3040.npy
#   Processed chunk 3041/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3041.npy
#   Processed chunk 3042/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3042.npy
#   Processed chunk 3043/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3043.npy
#   Processed chunk 3044/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3044.npy
#   Processed chunk 3045/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3045.npy
#   Processed chunk 3046/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3046.npy
#   Processed chunk 3047/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3047.npy
#   Processed chunk 3048/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3048.npy
#   Processed chunk 3049/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3049.npy
#   Processed chunk 3050/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3050.npy
#   Processed chunk 3051/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3051.npy
#   Processed chunk 3052/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3052.npy
#   Processed chunk 3053/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3053.npy
#   Processed chunk 3054/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3054.npy
#   Processed chunk 3055/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3055.npy
#   Processed chunk 3056/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3056.npy
#   Processed chunk 3057/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3057.npy
#   Processed chunk 3058/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3058.npy
#   Processed chunk 3059/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3059.npy
#   Processed chunk 3060/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3060.npy
#   Processed chunk 3061/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3061.npy
#   Processed chunk 3062/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3062.npy
#   Processed chunk 3063/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3063.npy
#   Processed chunk 3064/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3064.npy
#   Processed chunk 3065/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3065.npy
#   Processed chunk 3066/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3066.npy
#   Processed chunk 3067/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3067.npy
#   Processed chunk 3068/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3068.npy
#   Processed chunk 3069/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3069.npy
#   Processed chunk 3070/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3070.npy
#   Processed chunk 3071/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3071.npy
#   Processed chunk 3072/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3072.npy
#   Processed chunk 3073/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3073.npy
#   Processed chunk 3074/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3074.npy
#   Processed chunk 3075/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3075.npy
#   Processed chunk 3076/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3076.npy
#   Processed chunk 3077/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3077.npy
#   Processed chunk 3078/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3078.npy
#   Processed chunk 3079/3080
#   Saved /content/drive/MyDrive/N-MON/ALTRO/array_dataset/antennina2/3079.npy
#   Processed chunk 3080/3080
#   Completed 3080 chunks
#
# Total rows collected: 3080
# Completed antennina2, saved to /content/drive/MyDrive/N-MON/ALTRO/features_csv/features_file_antennina2.csv

# %%
import os, re

files = [f for f in os.listdir(base_array_dir) if f.endswith(".npy")]
idx = sorted(int(re.match(r"(\d+)\.npy$", f).group(1)) for f in files if re.match(r"(\d+)\.npy$", f))

expected = set(range(3080))
actual = set(idx)
missing = sorted(expected - actual)

print("count:", len(files))
print("min/max:", min(idx), max(idx))
print("missing:", missing[:30], "..." if len(missing) > 30 else "")
# Out:
# count: 3080
# min/max: 0 3079
# missing: []
